# %% [markdown]
# <a href="https://colab.research.google.com/github/saimim/Competitions/blob/main/RobiDatathon3tq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import seaborn as sb

import math

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.preprocessing import MinMaxScaler, StandardScaler, OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer

# Model Selection
from sklearn.model_selection import train_test_split, cross_val_score, KFold, StratifiedKFold, train_test_split, RepeatedStratifiedKFold

# Models
from sklearn.ensemble import HistGradientBoostingClassifier, GradientBoostingClassifier,RandomForestClassifier,ExtraTreesClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# !pip install catboost
from catboost import CatBoostClassifier

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score, roc_auc_score, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import VotingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import NuSVC
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from scipy.stats import zscore
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import joblib
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score
import warnings
warnings.simplefilter(action = "ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
box = pd.read_csv("/content/drive/MyDrive/Kaggle_ML_comp/RobiDataThon3/boxes.csv")
box
# Out:
#      BOX_ID   QUALITY                  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0         1   Premium              Home Delivery - CoD  0.00  2.70        9.96
# 1         2   Premium              Home Delivery - CoD  0.00  2.30       11.96
# 2         3   Premium              Home Delivery - CoD  0.00  2.40       11.96
# 3         4   Premium              Home Delivery - CoD  0.00  2.50       11.96
# 4         5   Premium              Home Delivery - CoD  0.00  2.60       11.96
# ..      ...       ...                              ...   ...   ...         ...
# 285     286  Standard  Home Delivery - Digital Payment  0.00  4.00       15.96
# 286     287  Standard  Home Delivery - Digital Payment  0.00  2.90       15.96
# 287     288  Standard  Home Delivery - Digital Payment  0.00  3.60       15.96
# 288     289  Standard  Home Delivery - Digital Payment  0.00  4.70       15.96
# 289     290  Standard  Home Delivery - Digital Payment 12.00  1.80       19.98
#
# [290 rows x 6 columns]

# %%
box.describe()
# Out:
#        BOX_ID   MILK   MEAT  UNIT_PRICE
# count  290.00 290.00 290.00      290.00
# mean   145.50   7.57   2.25       15.78
# std     83.86   6.40   1.15        4.10
# min      1.00   0.00   0.00        5.56
# 25%     73.25   0.00   1.80       12.82
# 50%    145.50   9.00   2.30       15.96
# 75%    217.75  12.00   2.90       19.98
# max    290.00  24.00   5.80       23.98

# %%
box.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BOX_ID           290 non-null    int64
#  1   QUALITY          290 non-null    object
#  2   DELIVERY_OPTION  290 non-null    object
#  3   MILK             290 non-null    float64
#  4   MEAT             290 non-null    float64
#  5   UNIT_PRICE       290 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 13.7+ KB

# %%
box.isnull().sum()
# Out:
# BOX_ID             0
# QUALITY            0
# DELIVERY_OPTION    0
# MILK               0
# MEAT               0
# UNIT_PRICE         0
# dtype: int64

# %%
test=pd.read_csv("/content/drive/MyDrive/Kaggle_ML_comp/RobiDataThon3/problem 1.csv")
test
# Out:
#          MAGIC_KEY
# 0      28D5BB06356
# 1      293BEAB4E98
# 2      2962EE8065C
# 3      2957BE29EA9
# 4      28E351A0745
# ...            ...
# 58684  28FB7C09776
# 58685  28E0E3B69BF
# 58686  28D343103A7
# 58687  290B1D6D5CB
# 58688  28FF193CB94
#
# [58689 rows x 1 columns]

# %%
submit=pd.read_csv("/content/drive/MyDrive/Kaggle_ML_comp/RobiDataThon3/sample submission 1.csv")
submit
# Out:
#          MAGIC_KEY PURCHASE
# 0      28D5BB06356        Y
# 1      293BEAB4E98        Y
# 2      2962EE8065C        Y
# 3      2957BE29EA9        Y
# 4      28E351A0745        Y
# ...            ...      ...
# 58684  28FB7C09776        Y
# 58685  28E0E3B69BF        Y
# 58686  28D343103A7        Y
# 58687  290B1D6D5CB        Y
# 58688  28FF193CB94        Y
#
# [58689 rows x 2 columns]

# %%
train=pd.read_csv("/content/drive/MyDrive/Kaggle_ML_comp/RobiDataThon3/purchase.csv")
train
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT
# 0            1/2/2019  2CED678A247   12.00       1.00
# 1            1/2/2019  2BF58D91BA1   12.00       1.00
# 2            1/2/2019  2C15B86534E   99.00       1.00
# 3            1/2/2019  2C32D9A859A    6.00       1.00
# 4            1/2/2019  2C7A55404D1    4.00       1.00
# ...               ...          ...     ...        ...
# 2455859    28/10/2018  2BD992B5538   12.00       1.00
# 2455860    28/10/2018  2C97CD72233   17.00       1.00
# 2455861    28/10/2018  2C91C61D372   40.00       1.00
# 2455862    28/10/2018  2CD70CFC4E3   51.00       1.00
# 2455863    28/10/2018  2C4792A5B84    4.00       1.00
#
# [2455864 rows x 4 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2455864 entries, 0 to 2455863
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   PURCHASE_DATE  object
#  1   MAGIC_KEY      object
#  2   BOX_ID         float64
#  3   BOX_COUNT      float64
# dtypes: float64(2), object(2)
# memory usage: 74.9+ MB

# %%
train.describe()
# Out:
#              BOX_ID    BOX_COUNT
# count  2,455,817.00 2,455,817.00
# mean         230.88         1.00
# std       29,233.30         0.04
# min            1.00        -1.00
# 25%          106.00         1.00
# 50%          143.00         1.00
# 75%          215.00         1.00
# max   11,111,111.00        19.00

# %%
train.isnull().sum()
# Out:
# PURCHASE_DATE     0
# MAGIC_KEY         0
# BOX_ID           47
# BOX_COUNT        47
# dtype: int64

# %%
test
# Out:
#          MAGIC_KEY
# 0      28D5BB06356
# 1      293BEAB4E98
# 2      2962EE8065C
# 3      2957BE29EA9
# 4      28E351A0745
# ...            ...
# 58684  28FB7C09776
# 58685  28E0E3B69BF
# 58686  28D343103A7
# 58687  290B1D6D5CB
# 58688  28FF193CB94
#
# [58689 rows x 1 columns]

# %%
pd.options.display.float_format = '{:,.2f}'.format
def summary(df):
    print(f'data shape: {train.shape}')
    summ = pd.DataFrame(train.dtypes, columns=['data type'])
    summ['#missing'] = train.isnull().sum().values
    summ['%missing'] = train.isnull().sum().values / len(df) * 100
    summ['#unique'] = train.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['min'] = desc['min'].values
    summ['max'] = desc['max'].values
    summ['average'] = desc['mean'].values
    summ['standard_deviation'] = desc['std'].values
    summ['first value'] = train.loc[0].values
    summ['second value'] = train.loc[1].values
    summ['third value'] = train.loc[2].values

    return summ
summary(train).style.background_gradient(cmap='YlOrBr')
# Out:
# data shape: (2455864, 4)
# <style type="text/css">
# #T_f4ae1_row0_col1, #T_f4ae1_row0_col2, #T_f4ae1_row0_col3, #T_f4ae1_row1_col1, #T_f4ae1_row1_col2, #T_f4ae1_row2_col3, #T_f4ae1_row3_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f4ae1_row1_col3, #T_f4ae1_row2_col1, #T_f4ae1_row2_col2, #T_f4ae1_row3_col1, #T_f4ae1_row3_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f4ae1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ae1_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_f4ae1_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_f4ae1_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_f4ae1_level0_col3" class="col_heading level0 col3" >#unique</th>
#       <th id="T_f4ae1_level0_col4" class="col_heading level0 col4" >min</th>
# ...

# %%
greater_than_100 = []
less_than_20 = []

# Iterate through columns
for column in train.columns:
    unique_values = train[column].unique()
    print(f"Total Unique value in {column}: {len(unique_values)}")

    # Check conditions and append to respective lists
    if len(unique_values) < 500:
        greater_than_100.append(column)
    elif len(unique_values) < 20:
        less_than_20.append(column)

# Print the lists
print("\nColumns with unique values greater than 500:", greater_than_100)
print("\nColumns with unique values less than 20:", less_than_20)
# Out:
# Total Unique value in PURCHASE_DATE: 151
# Total Unique value in MAGIC_KEY: 1274108
# Total Unique value in BOX_ID: 292
# Total Unique value in BOX_COUNT: 15
#
# Columns with unique values greater than 500: ['PURCHASE_DATE', 'BOX_ID', 'BOX_COUNT']
#
# Columns with unique values less than 20: []

# %%
for column in train.columns:
    unique_values = train[column].unique()
    print(f"Total Unique value in {column}: {len(unique_values)}")
    print(f"Unique values for {column}: {unique_values}")
# Out:
# Total Unique value in PURCHASE_DATE: 151
# Unique values for PURCHASE_DATE: ['1/2/2019' '2/2/2019' '3/2/2019' '4/2/2019' '5/2/2019' '6/2/2019'
#  '7/2/2019' '8/2/2019' '9/2/2019' '10/2/2019' '11/2/2019' '12/2/2019'
#  '13/2/2019' '14/2/2019' '15/2/2019' '16/2/2019' '17/2/2019' '18/2/2019'
#  '19/2/2019' '20/2/2019' '21/2/2019' '22/2/2019' '23/2/2019' '24/2/2019'
#  '25/2/2019' '26/2/2019' '27/2/2019' '28/2/2019' '1/1/2019' '2/1/2019'
#  '3/1/2019' '4/1/2019' '5/1/2019' '6/1/2019' '7/1/2019' '8/1/2019'
#  '9/1/2019' '10/1/2019' '11/1/2019' '12/1/2019' '13/1/2019' '14/1/2019'
#  '15/1/2019' '16/1/2019' '17/1/2019' '18/1/2019' '19/1/2019' '20/1/2019'
#  '21/1/2019' '22/1/2019' '23/1/2019' '24/1/2019' '25/1/2019' '26/1/2019'
#  '27/1/2019' '28/1/2019' '29/1/2019' '30/1/2019' '31/1/2019' '1/12/2018'
#  '2/12/2018' '3/12/2018' '4/12/2018' '5/12/2018' '6/12/2018' '7/12/2018'
#  '8/12/2018' '9/12/2018' '10/12/2018' '11/12/2018' '12/12/2018'
# ...

# %%
train2=train.copy()

# %%
most_frequent_value = train["BOX_ID"].mode() # Find the most frequent value

# %%
most_frequent_value
# Out:
# 0   163.00
# Name: BOX_ID, dtype: float64

# %%
most_frequent_value = train["BOX_ID"].mode()[0]

# Fill missing values in the "BOX_ID" column with the most frequent value
train = train.dropna()

# %%
train.isnull().sum()
# Out:
# PURCHASE_DATE    0
# MAGIC_KEY        0
# BOX_ID           0
# BOX_COUNT        0
# dtype: int64

# %%
train["BOX_ID"].replace(11111111, most_frequent_value, inplace=True)

# %%
box_count = train.groupby('BOX_ID').size()

# Find the BOX_ID with the highest count
most_purchased_box_id = box_count.idxmax()

# Print the most purchased BOX_ID and its count
print("Most purchased BOX_ID:", most_purchased_box_id)
print("Number of purchases:", box_count[most_purchased_box_id])
# Out:
# Most purchased BOX_ID: 163.0
# Number of purchases: 226565

# %%
# Group the DataFrame by BOX_ID
grouped_by_box_id = train.groupby('BOX_ID')

# Iterate over each group and display its details
for box_id, group_data in grouped_by_box_id:
    print("BOX_ID:", box_id)
    # print(group_data)
    print(group_data["BOX_COUNT"].sum())
# Out:
# BOX_ID: 1.0
# 1.0
# BOX_ID: 2.0
# 854.0
# BOX_ID: 3.0
# 13632.0
# BOX_ID: 4.0
# 12887.0
# BOX_ID: 5.0
# 474.0
# BOX_ID: 6.0
# 3287.0
# BOX_ID: 7.0
# 74.0
# BOX_ID: 8.0
# 33266.0
# BOX_ID: 9.0
# 6542.0
# BOX_ID: 10.0
# 473.0
# BOX_ID: 11.0
# 1.0
# BOX_ID: 12.0
# 8270.0
# BOX_ID: 13.0
# 6632.0
# BOX_ID: 14.0
# 4324.0
# BOX_ID: 15.0
# 2322.0
# BOX_ID: 16.0
# 1365.0
# BOX_ID: 17.0
# 4890.0
# BOX_ID: 18.0
# 36.0
# BOX_ID: 19.0
# 1.0
# BOX_ID: 20.0
# 47.0
# BOX_ID: 21.0
# 73.0
# BOX_ID: 22.0
# 75.0
# BOX_ID: 23.0
# 10722.0
# BOX_ID: 24.0
# 583.0
# BOX_ID: 25.0
# 97.0
# BOX_ID: 26.0
# 116.0
# BOX_ID: 27.0
# 23574.0
# BOX_ID: 28.0
# 4795.0
# BOX_ID: 29.0
# 6750.0
# BOX_ID: 30.0
# 5.0
# BOX_ID: 31.0
# 21669.0
# BOX_ID: 32.0
# 288.0
# BOX_ID: 33.0
# 2.0
# BOX_ID: 34.0
# 286.0
# BOX_ID: 35.0
# 3.0
# BOX_ID: 36.0
# 2.0
# BOX_ID: 37.0
# 3114.0
# BOX_ID: 38.0
# 241.0
# BOX_ID: 39.0
# 1589.0
# BOX_ID: 40.0
# 10697.0
# BOX_ID: 41.0
# 12655.0
# BOX_ID: 42.0
# 4023.0
# BOX_ID: 43.0
# 6.0
# ...

# %%
train.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2455817 entries, 0 to 2455863
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   PURCHASE_DATE  object
#  1   MAGIC_KEY      object
#  2   BOX_ID         float64
#  3   BOX_COUNT      float64
# dtypes: float64(2), object(2)
# memory usage: 93.7+ MB

# %%
# Convert "BOX_ID" column from float to int
train["BOX_ID"] = train["BOX_ID"].astype(int)

# Convert "BOX_COUNT" column from float to int
train["BOX_COUNT"] = train["BOX_COUNT"].astype(int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2455817 entries, 0 to 2455863
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   PURCHASE_DATE  object
#  1   MAGIC_KEY      object
#  2   BOX_ID         int64
#  3   BOX_COUNT      int64
# dtypes: int64(2), object(2)
# memory usage: 93.7+ MB

# %%
train
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT
# 0            1/2/2019  2CED678A247      12          1
# 1            1/2/2019  2BF58D91BA1      12          1
# 2            1/2/2019  2C15B86534E      99          1
# 3            1/2/2019  2C32D9A859A       6          1
# 4            1/2/2019  2C7A55404D1       4          1
# ...               ...          ...     ...        ...
# 2455859    28/10/2018  2BD992B5538      12          1
# 2455860    28/10/2018  2C97CD72233      17          1
# 2455861    28/10/2018  2C91C61D372      40          1
# 2455862    28/10/2018  2CD70CFC4E3      51          1
# 2455863    28/10/2018  2C4792A5B84       4          1
#
# [2455817 rows x 4 columns]

# %%
test
# Out:
#          MAGIC_KEY
# 0      28D5BB06356
# 1      293BEAB4E98
# 2      2962EE8065C
# 3      2957BE29EA9
# 4      28E351A0745
# ...            ...
# 58684  28FB7C09776
# 58685  28E0E3B69BF
# 58686  28D343103A7
# 58687  290B1D6D5CB
# 58688  28FF193CB94
#
# [58689 rows x 1 columns]

# %%
merged_train = pd.merge(train, box, on="BOX_ID", how="left")

# %%
merged_train
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0            1/2/2019  2CED678A247      12          1  Premium
# 1            1/2/2019  2BF58D91BA1      12          1  Premium
# 2            1/2/2019  2C15B86534E      99          1  Premium
# 3            1/2/2019  2C32D9A859A       6          1  Premium
# 4            1/2/2019  2C7A55404D1       4          1  Premium
# ...               ...          ...     ...        ...      ...
# 2455812    28/10/2018  2BD992B5538      12          1  Premium
# 2455813    28/10/2018  2C97CD72233      17          1  Premium
# 2455814    28/10/2018  2C91C61D372      40          1  Premium
# 2455815    28/10/2018  2CD70CFC4E3      51          1  Premium
# 2455816    28/10/2018  2C4792A5B84       4          1  Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0                   Home Delivery - CoD  8.00  1.50       12.98
# 1                   Home Delivery - CoD  8.00  1.50       12.98
# ...

# %%
merged_train.isnull().sum()
# Out:
# PURCHASE_DATE      0
# MAGIC_KEY          0
# BOX_ID             0
# BOX_COUNT          0
# QUALITY            0
# DELIVERY_OPTION    0
# MILK               0
# MEAT               0
# UNIT_PRICE         0
# dtype: int64

# %%
pd.options.display.float_format = '{:,.2f}'.format
def summary(df):
    print(f'data shape: {merged_train.shape}')
    summ = pd.DataFrame(merged_train.dtypes, columns=['data type'])
    summ['#missing'] = merged_train.isnull().sum().values
    summ['%missing'] = merged_train.isnull().sum().values / len(df) * 100
    summ['#unique'] = merged_train.nunique().values
    desc = pd.DataFrame(df.describe(include='all').transpose())


    return summ
summary(merged_train).style.background_gradient(cmap='YlOrBr')
# Out:
# data shape: (2455817, 9)
# <style type="text/css">
# #T_829bb_row0_col1, #T_829bb_row0_col2, #T_829bb_row0_col3, #T_829bb_row1_col1, #T_829bb_row1_col2, #T_829bb_row2_col1, #T_829bb_row2_col2, #T_829bb_row2_col3, #T_829bb_row3_col1, #T_829bb_row3_col2, #T_829bb_row3_col3, #T_829bb_row4_col1, #T_829bb_row4_col2, #T_829bb_row4_col3, #T_829bb_row5_col1, #T_829bb_row5_col2, #T_829bb_row5_col3, #T_829bb_row6_col1, #T_829bb_row6_col2, #T_829bb_row6_col3, #T_829bb_row7_col1, #T_829bb_row7_col2, #T_829bb_row7_col3, #T_829bb_row8_col1, #T_829bb_row8_col2, #T_829bb_row8_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_829bb_row1_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_829bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_829bb_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_829bb_level0_col1" class="col_heading level0 col1" >#missing</th>
# ...

# %%
merged_train["BOX_ID"].unique()
# Out:
# array([ 12,  99,   6,   4, 238, 227, 204, 231, 278, 201,  77,  80, 222,
#        228, 255, 106,  31, 162, 246,   8, 221, 174,  89,  76,  94, 108,
#        134, 131, 213, 220, 118, 141, 119, 142, 126, 103, 144, 258, 110,
#        245,  27,  42, 237, 203, 268, 163, 166, 252, 137, 198, 205, 217,
#        254, 271, 270, 272,  69, 138, 248, 269,  55,  52,  13,   3, 121,
#         72, 282,  51,  84,  85, 101,  65, 276, 223, 116,  32,  29,  82,
#         67, 177, 280, 130,  46, 104,  68,  26,  33,  44,  95, 232, 112,
#        225, 165,  54, 182, 196, 185,  64, 284,  60, 233, 128,  81,   1,
#         35, 215,  78,  90,  53, 230,   9,  87, 178,  96, 179, 229, 277,
#        200,  45,  36, 159, 281,  88, 288, 158,  92, 194, 168, 275,  63,
#        241, 115, 152,  75, 256, 117, 210,  23, 266, 155, 154,  59, 123,
#        124,  24,  28, 176,   5,   7, 285,  30, 181, 143,  43, 286, 187,
#        283, 224, 184, 244, 148, 250, 289, 259, 251, 206, 209, 290, 212,
# ...

# %%
merged_train
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0            1/2/2019  2CED678A247      12          1  Premium
# 1            1/2/2019  2BF58D91BA1      12          1  Premium
# 2            1/2/2019  2C15B86534E      99          1  Premium
# 3            1/2/2019  2C32D9A859A       6          1  Premium
# 4            1/2/2019  2C7A55404D1       4          1  Premium
# ...               ...          ...     ...        ...      ...
# 2455812    28/10/2018  2BD992B5538      12          1  Premium
# 2455813    28/10/2018  2C97CD72233      17          1  Premium
# 2455814    28/10/2018  2C91C61D372      40          1  Premium
# 2455815    28/10/2018  2CD70CFC4E3      51          1  Premium
# 2455816    28/10/2018  2C4792A5B84       4          1  Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0                   Home Delivery - CoD  8.00  1.50       12.98
# 1                   Home Delivery - CoD  8.00  1.50       12.98
# ...

# %%
merged_train2 = merged_train.merge(test[['MAGIC_KEY']], on='MAGIC_KEY', how='inner')

# %%
merged_train2
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0           1/2/2019  293587823F7     204          1  Standard
# 1          13/2/2019  293587823F7     204          1  Standard
# 2          28/2/2019  293587823F7     272          1  Standard
# 3           6/1/2019  293587823F7     238          1  Standard
# 4          3/12/2018  293587823F7     203          1  Standard
# ...              ...          ...     ...        ...       ...
# 218597    31/12/2018  2903D1BF578     255          1  Standard
# 218598    30/11/2018  2903D1BF578     255          1  Standard
# 218599    10/10/2018  2903D1BF578     247          1  Standard
# 218600     31/1/2019  28FD73EE76B     237          1  Standard
# 218601     6/12/2018  28FD73EE76B     258          1  Standard
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0                  Home Delivery - CoD 10.70  0.00       12.78
# 1                  Home Delivery - CoD 10.70  0.00       12.78
# ...

# %%
merged_train2['BOX_COUNT'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
# Count the occurrences of each value in the "BOX_COUNT" column
occurrences = merged_train2['BOX_COUNT'].value_counts()

# Check if -1 exists in the index (values) of the occurrences
if -1 in occurrences.index:
    # Get the count of occurrences of -1
    count_of_minus_1 = occurrences[-1]
    print("Occurrences of -1 in the 'BOX_COUNT' column:", count_of_minus_1)
else:
    print("Occurrences of -1 in the 'BOX_COUNT' column: 0")
# Out:
# Occurrences of -1 in the 'BOX_COUNT' column: 0

# %%
greater_than_zero_milk = merged_train2[(new_train['MILK'] > 0.0)]

# %%
greater_than_zero_milk
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0           1/2/2019  293587823F7     204          1  Standard
# 1          13/2/2019  293587823F7     204          1  Standard
# 2          28/2/2019  293587823F7     272          1  Standard
# 3           6/1/2019  293587823F7     238          1  Standard
# 4          3/12/2018  293587823F7     203          1  Standard
# ...              ...          ...     ...        ...       ...
# 218593     31/1/2019  29040F627CB     272          1  Standard
# 218594    11/12/2018  29040F627CB     271          1  Standard
# 218595    11/10/2018  29040F627CB     260          1  Standard
# 218600     31/1/2019  28FD73EE76B     237          1  Standard
# 218601     6/12/2018  28FD73EE76B     258          1  Standard
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0                  Home Delivery - CoD 10.70  0.00       12.78
# 1                  Home Delivery - CoD 10.70  0.00       12.78
# ...

# %%
greater_than_zero_meat = merged_train2[(new_train['MEAT'] > 0.0)]

# %%
# Filter rows where both "MILK" and "MEAT" are greater than 0
both_greater_than_zero = merged_train2[(new_train['MILK'] > 0) & (new_train['MEAT'] > 0)]

# Display the filtered DataFrame
print(both_greater_than_zero[['MILK', 'MEAT']])
# Out:
#         MILK  MEAT
# 2      16.00  2.20
# 5      18.00  2.90
# 11     16.00  2.20
# 12      8.00  2.20
# 13      8.00  2.20
# ...      ...   ...
# 218585 12.00  1.80
# 218593 16.00  2.20
# 218594 16.00  1.80
# 218595 10.00  1.80
# 218601  8.00  2.20
#
# [91179 rows x 2 columns]

# %%
merged_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2455817 entries, 0 to 2455816
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PURCHASE_DATE    object
#  1   MAGIC_KEY        object
#  2   BOX_ID           int64
#  3   BOX_COUNT        int64
#  4   QUALITY          object
#  5   DELIVERY_OPTION  object
#  6   MILK             float64
#  7   MEAT             float64
#  8   UNIT_PRICE       float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 168.6+ MB

# %%
new_train2=merged_train2.copy()

# %%
# Define a function to determine the purchase label
def determine_purchase_label(row):
    if row['MILK'] <= 0:
      return 'N'
    if row['MEAT'] <= 0:
          return 'N'
    else:
        return 'Y'

# Apply the function to each row and create a new column 'purchase'
new_train2['purchase'] = merged_train2.apply(determine_purchase_label, axis=1)

# %%
new_train2
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0           1/2/2019  293587823F7     204          1  Standard
# 1          13/2/2019  293587823F7     204          1  Standard
# 2          28/2/2019  293587823F7     272          1  Standard
# 3           6/1/2019  293587823F7     238          1  Standard
# 4          3/12/2018  293587823F7     203          1  Standard
# ...              ...          ...     ...        ...       ...
# 218597    31/12/2018  2903D1BF578     255          1  Standard
# 218598    30/11/2018  2903D1BF578     255          1  Standard
# 218599    10/10/2018  2903D1BF578     247          1  Standard
# 218600     31/1/2019  28FD73EE76B     237          1  Standard
# 218601     6/12/2018  28FD73EE76B     258          1  Standard
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE purchase
# 0                  Home Delivery - CoD 10.70  0.00       12.78        N
# ...

# %%
purchase_counts = new_train2["purchase"].value_counts()

# %%
purchase_counts
# Out:
# purchase
# N    127423
# Y     91179
# Name: count, dtype: int64

# %%
new_train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218602 entries, 0 to 218601
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   PURCHASE_DATE    218602 non-null  object
#  1   MAGIC_KEY        218602 non-null  object
#  2   BOX_ID           218602 non-null  int64
#  3   BOX_COUNT        218602 non-null  int64
#  4   QUALITY          218602 non-null  object
#  5   DELIVERY_OPTION  218602 non-null  object
#  6   MILK             218602 non-null  float64
#  7   MEAT             218602 non-null  float64
#  8   UNIT_PRICE       218602 non-null  float64
#  9   purchase         218602 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 16.7+ MB

# %%
new_train2["MAGIC_KEY"].value_counts().sum()
# Out:
# 218602

# %%
# Define a dictionary to map 'Y' to 1 and 'N' to 2
mapping = {'Y': 1, 'N': 2}

# Map the values in the "purchase" column
new_train2["purchase"] = new_train2["purchase"].map(mapping)

# Display the updated DataFrame
print(new_train2)
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0           1/2/2019  293587823F7     204          1  Standard
# 1          13/2/2019  293587823F7     204          1  Standard
# 2          28/2/2019  293587823F7     272          1  Standard
# 3           6/1/2019  293587823F7     238          1  Standard
# 4          3/12/2018  293587823F7     203          1  Standard
# ...              ...          ...     ...        ...       ...
# 218597    31/12/2018  2903D1BF578     255          1  Standard
# 218598    30/11/2018  2903D1BF578     255          1  Standard
# 218599    10/10/2018  2903D1BF578     247          1  Standard
# 218600     31/1/2019  28FD73EE76B     237          1  Standard
# 218601     6/12/2018  28FD73EE76B     258          1  Standard
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  purchase
# 0                  Home Delivery - CoD 10.70  0.00       12.78         2
# ...

# %%
new_train2
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0           1/2/2019  293587823F7     204          1  Standard
# 1          13/2/2019  293587823F7     204          1  Standard
# 2          28/2/2019  293587823F7     272          1  Standard
# 3           6/1/2019  293587823F7     238          1  Standard
# 4          3/12/2018  293587823F7     203          1  Standard
# ...              ...          ...     ...        ...       ...
# 218597    31/12/2018  2903D1BF578     255          1  Standard
# 218598    30/11/2018  2903D1BF578     255          1  Standard
# 218599    10/10/2018  2903D1BF578     247          1  Standard
# 218600     31/1/2019  28FD73EE76B     237          1  Standard
# 218601     6/12/2018  28FD73EE76B     258          1  Standard
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  purchase
# 0                  Home Delivery - CoD 10.70  0.00       12.78         2
# ...

# %%
new_train2.to_csv("Problem1Data.CSV")

# %%
test_missing_keys = test[~test['MAGIC_KEY'].isin(new_train2['MAGIC_KEY'])]

# %%
test_missing_keys
# Out:
# Empty DataFrame
# Columns: [MAGIC_KEY]
# Index: []

# %%
new_train2['PURCHASE_DATE'] = pd.to_datetime(new_train2['PURCHASE_DATE'], format='%d/%m/%Y')

# Sort the dataframe by 'PURCHASE_DATE' column in ascending order
merged_train2_sorted = new_train2.sort_values(by='PURCHASE_DATE', ascending=False)

# %%
merged_train2_sorted
# Out:
#        PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 175373    2019-02-28  28E3E70AC81     209          1  Standard
# 175677    2019-02-28  28EDEE6E384     251          1  Standard
# 175704    2019-02-28  28FD9026DEA     272          1  Standard
# 175700    2019-02-28  28D872979C0     272          1  Standard
# 175698    2019-02-28  28EE6CCA361     271          1  Standard
# ...              ...          ...     ...        ...       ...
# 559       2018-10-01  28EEDA4692F     260          1  Standard
# 76261     2018-10-01  2956ECB6492     247          1  Standard
# 18240     2018-10-01  2903CD4E98F     247          1  Standard
# 111149    2018-10-01  29790E3488F     207          1  Standard
# 18300     2018-10-01  297291321DB     260          1  Standard
#
#                        DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  purchase
# 175373             Home Delivery - CoD  0.00  4.00       15.96         2
# ...

# %%
merged_train2_sorted.to_csv('date_marged_data.csv')

# %%
merged_train2_sorted['BOX_COUNT'].unique()
# Out:
# array([1, 2, 3, 4])
